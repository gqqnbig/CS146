# %%
# %run /src/regression.py
# Out:
# ERROR:root:File `'/src/regression.py'` not found.

# %%
# %run src/regression.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Desktop\Jupyter\src\regression.py in <module>()
#     344
#     345 if __name__ == "__main__" :
# --> 346     main()
#
# ~\Desktop\Jupyter\src\regression.py in main()
#     310 def main() :
#     311     # load data
# --> 312     test_data = load_data("regression_test.csv")
#     313     train_data = load_data("regression_train.csv")
#     314
#
# ~\Desktop\Jupyter\src\regression.py in load_data(filename)
#      66 def load_data(filename) :
#      67     data = Data()
# ---> 68     data.load(filename)
#      69     return data
#      70
#
# ~\Desktop\Jupyter\src\regression.py in load(self, filename)
#      45
#      46         # load data
# ---> 47         with open(f, 'r') as fid :
#      48             data = np.loadtxt(fid, delimiter=",")
#      49
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\data\\regression_test.csv'

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# number of iterations: 10000
# number of iterations: 765
# number of iterations: 7021
# number of iterations: 10000
# Investigating polynomial regression...
# Done!

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# number of iterations: 10000
# 2.71091652001e+39
# number of iterations: 765
# 3.91257640579
# number of iterations: 7021
# 3.91257640579
# number of iterations: 10000
# 4.0863970368
# Investigating polynomial regression...
# Done!

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# number of iterations: 10000
# 2.71091652001e+39
# number of iterations: 765
# 3.91257640579
# number of iterations: 7021
# 3.91257640579
# number of iterations: 10000
# 4.0863970368
# Investigating polynomial regression...
# Done!

# %%
a = [1,2,3]

# %%
a[::-1]
# Out:
# [3, 2, 1]

# %%
a[1::-1]
# Out:
# [2, 1]

# %%
a[:-2:-1]
# Out:
# [3]

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# number of iterations: 10000
# 2.71091652001e+39
# [ -9.40470931e+18  -4.65229095e+18]
# number of iterations: 765
# 3.91257640579
# [ 2.44640703 -2.81635347]
# number of iterations: 7021
# 3.91257640579
# [ 2.4464068 -2.816353 ]
# number of iterations: 10000
# 4.0863970368
# [ 2.27044798 -2.46064834]
# Investigating polynomial regression...
# Done!

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# Investigating gradient descent...
# number of iterations: 10000
# time taken:  0.2276136875152588
# model cost:  2.71091652001e+39
# coefficent vector: [ -9.40470931e+18  -4.65229095e+18]
# number of iterations: 765
# time taken:  0.022051572799682617
# model cost:  3.91257640579
# coefficent vector: [ 2.44640703 -2.81635347]
# number of iterations: 7021
# time taken:  0.15541768074035645
# model cost:  3.91257640579
# coefficent vector: [ 2.4464068 -2.816353 ]
# number of iterations: 10000
# time taken:  0.24161338806152344
# model cost:  4.0863970368
# coefficent vector: [ 2.27044798 -2.46064834]
#
# Investigating closed form...
# time taken:  0.0
# coefficent vector:  [ 2.44640709 -2.81635359]
# Investigating varied eta...
# number of iterations: 616
# time taken:  0.018046855926513672
# model cost:  3.91257640579
# coefficent vector: [ 2.44640732 -2.81635404]
# Investigating polynomial regression...
# Done!

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# Investigating gradient descent...
# number of iterations: 10000
# time taken:  0.21859288215637207
# model cost:  2.71091652001e+39
# coefficent vector: [ -9.40470931e+18  -4.65229095e+18]
# number of iterations: 765
# time taken:  0.017040014266967773
# model cost:  3.91257640579
# coefficent vector: [ 2.44640703 -2.81635347]
# number of iterations: 7021
# time taken:  0.17345857620239258
# model cost:  3.91257640579
# coefficent vector: [ 2.4464068 -2.816353 ]
# number of iterations: 10000
# time taken:  0.22256016731262207
# model cost:  4.0863970368
# coefficent vector: [ 2.27044798 -2.46064834]
#
# Investigating closed form...
# time taken:  0.0
# coefficent vector:  [ 2.44640709 -2.81635359]
# Investigating varied eta...
# number of iterations: 1679
# time taken:  0.05411362648010254
# model cost:  3.91257640579
# coefficent vector: [ 2.44640678 -2.81635296]
# Investigating polynomial regression...
# Done!

# %%
[1,2,3,1].index(1)
# Out:
# 0

# %%
# %run src/regression.py
# Out:
# Visualizing data...
# Investigating linear regression...
# Cost for part(d): 40.233847409671
# Investigating gradient descent...
# number of iterations: 10000
# time taken:  0.19649434089660645
# model cost:  2.71091652001e+39
# coefficent vector: [ -9.40470931e+18  -4.65229095e+18]
# number of iterations: 765
# time taken:  0.023061513900756836
# model cost:  3.91257640579
# coefficent vector: [ 2.44640703 -2.81635347]
# number of iterations: 7021
# time taken:  0.16941452026367188
# model cost:  3.91257640579
# coefficent vector: [ 2.4464068 -2.816353 ]
# number of iterations: 10000
# time taken:  0.23963689804077148
# model cost:  4.0863970368
# coefficent vector: [ 2.27044798 -2.46064834]
#
# Investigating closed form...
# time taken:  0.0010004043579101562
# coefficent vector:  [ 2.44640709 -2.81635359]
# Investigating varied eta...
# number of iterations: 1679
# time taken:  0.05415463447570801
# model cost:  3.91257640579
# coefficent vector: [ 2.44640678 -2.81635296]
# Investigating polynomial regression...
# best fit on training data with degree: 10, training error: 0.211689163163471, test error: 2.0077034764205193
# best fit on test data with degree: 5, training error: 0.22681133051783212, test error: 0.3551377428840611
# Done!
